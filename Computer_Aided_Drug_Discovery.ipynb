# %% [markdown]
# <a href="https://colab.research.google.com/github/sunaina1701/Computer-Aided-Drug-Discovery/blob/main/Computer_Aided_Drug_Discovery.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Computer-Aided Drug Discovery (CADD)_ChEMBL
! pip install chembl_webresource_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 5.6 MB/s eta 0:00:00
# ...

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
# Target search for protease
target = new_client.target
target_query = target.search('protease')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#     cross_references                                         organism  \
# 0                 []                             Human rhinovirus sp.
# 1                 []                   Human immunodeficiency virus 1
# 2                 []                     Human immunodeficiency virus
# 3                 []                     Human T-lymphotropic virus 1
# 4                 []        Norovirus Hu/GII.4-2002/WeertE022/2002/NL
# ..               ...                                              ...
# 714               []  Severe acute respiratory syndrome coronavirus 2
# 715               []                                     Homo sapiens
# 716               []                                     Homo sapiens
# 717               []                                     Homo sapiens
# 718               []                                     Homo sapiens
#
#                        pref_name  score  species_group_flag target_chembl_id  \
# ...

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL2857'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)
df
# Out:
#     action_type activity_comment  activity_id activity_properties  \
# 0          None             None        32933                  []
# 1          None             None        32934                  []
# 2          None             None        32939                  []
# 3          None             None        35426                  []
# 4          None             None        35428                  []
# ..          ...              ...          ...                 ...
# 325        None             None      1183582                  []
# 326        None             None      1183583                  []
# 327        None             None      1183584                  []
# 328        None             None      1254163                  []
# 329        None             None      1720306                  []
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL766325  Inhibitory activity against human cytomegalovi...
# ...

# %%
df.to_csv('protease_bioactivity_data_raw.csv', index=False)

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# <ipython-input-49-955aac5800f0>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#     action_type activity_comment  activity_id activity_properties  \
# 0          None             None        32933                  []
# 1          None             None        32934                  []
# 2          None             None        32939                  []
# 3          None             None        35426                  []
# 4          None             None        35428                  []
# ..          ...              ...          ...                 ...
# 325        None             None      1183582                  []
# 326        None             None      1183583                  []
# 327        None             None      1183584                  []
# 328        None             None      1254163                  []
# 329        None             None      1720306                  []
#
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 285

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#     action_type activity_comment  activity_id activity_properties  \
# 0          None             None        32933                  []
# 1          None             None        32934                  []
# 2          None             None        32939                  []
# 3          None             None        35426                  []
# 4          None             None        35428                  []
# ..          ...              ...          ...                 ...
# 325        None             None      1183582                  []
# 326        None             None      1183583                  []
# 327        None             None      1183584                  []
# 328        None             None      1254163                  []
# 329        None             None      1720306                  []
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL766325  Inhibitory activity against human cytomegalovi...
# ...

# %%
#Data pre-processing of the bioactivity data
#(molecule_chembl_id,canonical_smiles,standard_value)
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL99102  CCC[C@@H](NC(=O)N1C(=O)C[C@@H]1Cc1ccccc1)c1ccccc1
# 1          CHEMBL97927             O=C1C[C@H](Cc2ccccc2)N1C(=O)NCc1ccncc1
# 2         CHEMBL318278     COc1ccc(CN(C)C(=O)N2C(=O)C[C@@H]2Cc2ccccc2)cc1
# 3         CHEMBL100212            O=C1C[C@H](Cc2ccccc2)N1C(=O)NCCc1ccccc1
# 4          CHEMBL95260    CS[C@@H]1C(=O)N(C(=O)NCc2ccncc2)[C@H]1Cc1ccccc1
# ..                 ...                                                ...
# 325       CHEMBL422084  CC(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@@H](CC(N)=O)...
# 326       CHEMBL424081  CC(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@@H](CCC(N)=O...
# 327       CHEMBL337383  CC(NC(=O)[C@H](CC(=O)N(C)C)NC(=O)[C@@H](NC(=O)...
# 328       CHEMBL267571  Cc1cccc(C)c1OCC(=O)N[C@@H](Cc1ccccc1)[C@H](O)C...
# 329       CHEMBL358279       NC(=O)c1ccc2c(c1)C(=O)C(=O)N2Cc1ccc2ccccc2c1
#
#     standard_value
# 0           3400.0
# 1          12000.0
# ...

# %%
#Saves dataframe to CSV file
df3.to_csv('protease_02_bioactivity_data_preprocessed.csv', index=False)

# %%
df4 = pd.read_csv('protease_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL99102  CCC[C@@H](NC(=O)N1C(=O)C[C@@H]1Cc1ccccc1)c1ccccc1
# 1          CHEMBL97927             O=C1C[C@H](Cc2ccccc2)N1C(=O)NCc1ccncc1
# 2         CHEMBL318278     COc1ccc(CN(C)C(=O)N2C(=O)C[C@@H]2Cc2ccccc2)cc1
# 3         CHEMBL100212            O=C1C[C@H](Cc2ccccc2)N1C(=O)NCCc1ccccc1
# 4          CHEMBL95260    CS[C@@H]1C(=O)N(C(=O)NCc2ccncc2)[C@H]1Cc1ccccc1
# ..                 ...                                                ...
# 280       CHEMBL422084  CC(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@@H](CC(N)=O)...
# 281       CHEMBL424081  CC(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@@H](CCC(N)=O...
# 282       CHEMBL337383  CC(NC(=O)[C@H](CC(=O)N(C)C)NC(=O)[C@@H](NC(=O)...
# 283       CHEMBL267571  Cc1cccc(C)c1OCC(=O)N[C@@H](Cc1ccccc1)[C@H](O)C...
# 284       CHEMBL358279       NC(=O)c1ccc2c(c1)C(=O)C(=O)N2Cc1ccc2ccccc2c1
#
#      standard_value         class
# 0            3400.0  intermediate
# ...

# %%
#Saves dataframe to CSV file
df5.to_csv('protease_03_bioactivity_data_curated.csv', index=False)

# %%
! zip protease.zip *.csv
# Out:
#   adding: protease_02_bioactivity_data_preprocessed.csv (deflated 82%)
#   adding: protease_03_bioactivity_data_curated.csv (deflated 83%)
#   adding: protease_bioactivity_data_raw.csv (deflated 90%)
